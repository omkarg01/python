# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
df = pd.read_csv('..\\ML\\7_logistic_reg\\insurance_data.csv')

# %%
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test= train_test_split(df[['age']], df.bought_insurance,train_size=0.9)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
X_train.values
# Out:
# array([[22],
#        [19],
#        [60],
#        [23],
#        [49],
#        [54],
#        [47],
#        [25],
#        [62],
#        [46],
#        [25],
#        [55],
#        [52],
#        [50],
#        [28],
#        [61],
#        [55],
#        [40],
#        [18],
#        [45],
#        [18],
#        [29],
#        [26],
#        [56]], dtype=int64)

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([1, 0, 0], dtype=int64)

# %%
y_test
# Out:
# 17    1
# 12    0
# 20    0
# Name: bought_insurance, dtype: int64

# %%
model.score(X_test, y_test)
# Out:
# 1.0

# %%
model.predict_proba(X_test)
# Out:
# array([[0.07775318, 0.92224682],
#        [0.80422008, 0.19577992],
#        [0.89706595, 0.10293405]])

# %%
df1 = pd.read_csv('..\\ML\\7_logistic_reg\\Exercise\\HR_comma_sep.csv')

# %%
df1
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df1 = pd.concat((df1,pd.get_dummies(df1.salary)),axis='columns').drop(['salary','last_evaluation','number_project','Work_accident','Department','time_spend_company'],axis='columns')

# %%
df1.drop('left',axis='columns')
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  high  \
# 0                    0.38                   157                      0     0
# 1                    0.80                   262                      0     0
# 2                    0.11                   272                      0     0
# 3                    0.72                   223                      0     0
# 4                    0.37                   159                      0     0
# ...                   ...                   ...                    ...   ...
# 14994                0.40                   151                      0     0
# 14995                0.37                   160                      0     0
# 14996                0.37                   143                      0     0
# 14997                0.11                   280                      0     0
# 14998                0.37                   158                      0     0
#
#        low  medium
# 0        1       0
# ...

# %%
X_train, X_test, y_train, y_test=train_test_split(df1.drop('left',axis='columns'), df1.left, train_size = 0.9)

# %%
X_train
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  high  \
# 7894                 0.70                   182                      0     0
# 11749                0.49                   240                      0     0
# 466                  0.37                   134                      0     0
# 9045                 0.94                   273                      0     1
# 6737                 0.83                   242                      0     0
# ...                   ...                   ...                    ...   ...
# 10511                0.49                   213                      0     0
# 5859                 0.70                   257                      0     0
# 13094                0.48                   198                      0     0
# 467                  0.09                   292                      0     0
# 13620                0.87                   207                      0     1
#
#        low  medium
# 7894     1       0
# ...

# %%
y_train
# Out:
# 7894     0
# 11749    0
# 466      1
# 9045     0
# 6737     0
#         ..
# 10511    0
# 5859     0
# 13094    0
# 467      1
# 13620    0
# Name: left, Length: 13499, dtype: int64

# %%
model.fit(X_train, y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
 model.predict(X_test)
# Out:
# array([0, 1, 0, ..., 0, 0, 0], dtype=int64)

# %%
model.score(X_test, y_test)
# Out:
# 0.7866666666666666

# %%
X_train[X_train['promotion_last_5years']==1]
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  high  \
# 10855                0.77                   175                      1     0
# 13670                0.84                   197                      1     0
# 13480                0.70                   214                      1     0
# 13677                0.68                   213                      1     0
# 5522                 0.78                   252                      1     1
# ...                   ...                   ...                    ...   ...
# 13393                0.48                   250                      1     0
# 14036                0.29                   134                      1     0
# 13066                0.77                   175                      1     0
# 13427                0.50                   163                      1     0
# 11219                0.48                   275                      1     0
#
#        low  medium
# 10855    0       1
# ...

# %%
model.predict([[0.85,300,1,1,0,0]])
# Out:
# array([0], dtype=int64)

# %%
df1
# Out:
#        satisfaction_level  average_montly_hours  left  promotion_last_5years  \
# 0                    0.38                   157     1                      0
# 1                    0.80                   262     1                      0
# 2                    0.11                   272     1                      0
# 3                    0.72                   223     1                      0
# 4                    0.37                   159     1                      0
# ...                   ...                   ...   ...                    ...
# 14994                0.40                   151     1                      0
# 14995                0.37                   160     1                      0
# 14996                0.37                   143     1                      0
# 14997                0.11                   280     1                      0
# 14998                0.37                   158     1                      0
#
#        high  low  medium
# ...

# %%
df1[df1['high'] & df1['left'] == 1]
# Out:
#        satisfaction_level  average_montly_hours  left  promotion_last_5years  \
# 72                   0.45                   149     1                      0
# 111                  0.09                   289     1                      0
# 189                  0.44                   156     1                      0
# 267                  0.45                   129     1                      0
# 306                  0.37                   149     1                      0
# ...                   ...                   ...   ...                    ...
# 14829                0.45                   148     1                      0
# 14868                0.43                   130     1                      0
# 14902                0.45                   159     1                      0
# 14941                0.43                   131     1                      0
# 14980                0.76                   238     1                      0
#
#        high  low  medium
# ...

# %%
df1[(df1['high'] == 1 ) & (df1['left'] == 0)]
# Out:
#        satisfaction_level  average_montly_hours  left  promotion_last_5years  \
# 2022                 0.75                   144     0                      0
# 2061                 0.82                   148     0                      0
# 2100                 0.56                   215     0                      0
# 2139                 0.71                   172     0                      0
# 2178                 0.21                   207     0                      0
# ...                   ...                   ...   ...                    ...
# 14205                0.22                   193     0                      1
# 14206                0.90                   259     0                      1
# 14207                0.74                   266     0                      1
# 14208                0.85                   185     0                      1
# 14209                0.33                   172     0                      1
#
#        high  low  medium
# ...

# %%
plt.hist(df1[(df1['high'] == 1 ) & (df1['left'] == 0)])
# Out:
# (array([[6., 0., 0., ..., 0., 0., 0.],
#         [6., 0., 0., ..., 0., 0., 0.],
#         [6., 0., 0., ..., 1., 0., 0.],
#         ...,
#         [6., 0., 0., ..., 0., 0., 1.],
#         [6., 0., 0., ..., 0., 0., 0.],
#         [6., 0., 0., ..., 0., 0., 0.]]),
#  array([  0. ,  28.7,  57.4,  86.1, 114.8, 143.5, 172.2, 200.9, 229.6,
#         258.3, 287. ]),
#  <a list of 1155 Lists of Patches objects>)

# %%
array = np.array([6,3,6,2,2])

# %%
plt.hist(array)
plt.showplt.
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
df2 = pd.read_csv('..\\ML\\7_logistic_reg\\Exercise\\HR_comma_sep.csv')

# %%
df2.drop(['last_evaluation','number_project','Work_accident','Department','time_spend_company'],axis='columns', inplace=True)

# %%
df2
# Out:
#        satisfaction_level  average_montly_hours  left  promotion_last_5years  \
# 0                    0.38                   157     1                      0
# 1                    0.80                   262     1                      0
# 2                    0.11                   272     1                      0
# 3                    0.72                   223     1                      0
# 4                    0.37                   159     1                      0
# ...                   ...                   ...   ...                    ...
# 14994                0.40                   151     1                      0
# 14995                0.37                   160     1                      0
# 14996                0.37                   143     1                      0
# 14997                0.11                   280     1                      0
# 14998                0.37                   158     1                      0
#
#        salary
# 0         low
# ...

# %%
pd.crosstab(df2.salary, df2.left).plot(kind='bar')

# %%
df3 = pd.read_csv('..\\ML\\7_logistic_reg\\Exercise\\HR_comma_sep.csv')

# %%
df3
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
pd.crosstab(df3.Department, df3.left).plot(kind='bar')
