# %%
import xlrd
import xlsxwriter
import pandas as pd
# import pandas.ExcelWriter as ExcelWriter

# %%
xlsx_df = pd.read_excel('cut_off.xlsx',index_col=[0], skiprows =[2],header=[0,1])
xlsx_df['COLLEGE NAME'].columns #= ' '*len(list(xlsx_df['COLLEGE NAME'].columns)[0])
# list(xlsx_df['COLLEGE NAME'].columns)[0]
# xlsx_df.columns.set_levels(['GOBC','LOBC','GOBC','LOBC','GOBC','LOBC'],level=1,inplace=True)
xlsx_df
# Out:
#                             COLLEGE NAME                                CITY  \
#                       Unnamed: 1_level_1                  Unnamed: 2_level_1
# 3012                            V.J.T.I.                             Matunga
# 3036                                 ICT                             Matunga
# 3181                       K. J. Somaiya                          Vidyavihar
# 3183                  M. H. Saboo Siddik                             Byculla
# 3193                S.S. Jondhale (SSJD)                           Dombivali
# 3198             Konkan Gyanpeth (KGCOE)                              Karjat
# 3208                           Don Bosco                          Vidyavihar
# 3209                        K.J. Somaiya                                Sion
# 3210                        K.C. College                               Thane
# 3217                       S.S. Jhondale                            Asangoan
# ...

# %%
with ExcelWriter('cut_off.xlsx') as writer:
    df.to_excel(writer)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-eaa2a995fd4c> in <module>
# ----> 1 with ExcelWriter('cut_off.xlsx') as writer:
#       2     df.to_excel(writer)
#
# NameError: name 'ExcelWriter' is not defined

# %%
wbRD = xlrd.open_workbook("cut_off.xlsx")

# %%
sheets = wbRD.sheets()

# %%
wb = xlsxwriter.Workbook('cut_off.xlsx')

# %%
worksheet = wb.add_worksheet('Hfello')

# %%
worksheet.set_column('A:A', 20)
# Out:
# 0

# %%
wb.close()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\xlsxwriter\workbook.py in close(self)
#     315             try:
# --> 316                 self._store_workbook()
#     317             except IOError as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\xlsxwriter\workbook.py in _store_workbook(self)
#     631         except IOError as e:
# --> 632             raise e
#     633
#
# C:\ProgramData\Anaconda3\lib\site-packages\xlsxwriter\workbook.py in _store_workbook(self)
#     628         try:
# --> 629             xlsx_file = ZipFile(self.filename, "w", compression=ZIP_DEFLATED,
#     630                                 allowZip64=self.allow_zip64)
#
# C:\ProgramData\Anaconda3\lib\zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1249                 try:
# ...
