# %%
# !pip install tabula-py

# %%
import pdftables_api
import pandas as pd
import tabula
import re

# %%
# !pip install https://github.com/pdftables/python-pdftables-api/archive/master.tar.gz

# %%
c = pdftables_api.Client('fvwdh6pwcp21')

# %%
c.xlsx('DISPLAY_PDF_DSE_SD_2020_2021_FINAL.pdf', 'output2020(2).xlsx')
# Out:
# ---------------------------------------------------------------------------
# ConnectionAbortedError                    Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     391         else:
# --> 392             conn.request(method, url, **httplib_request_kw)
#     393
#
# C:\ProgramData\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1239         """Send a complete request to the server."""
# ...

# %%
from tabula.io import read_pdf
from tabula.io import convert_into

# %%
tabula.io.convert_into("DISPLAY_PDF_DSE_SD_2020_2021_FINAL.pdf", "output2020(1).csv", output_format="csv", pages='all')

# %%
df = tabula.io.read_pdf("DISPLAY_PDF_DSE_SD_2020_2021_FINAL.pdf",pages="all", pandas_options={"header":None},lattice=True, area=[50,0,800,1000],stream=True,multiple_tables=True)
# df[2]
# Out:
#                                                     0  \
# 0        Main Group : 01 - Chemical Engineering Group
# 1              Sub Group : 0101 - Chemical Technology
# 2                                           Sr No : 1
# 3                            Choice Code  : 602851510
# 4                                  Non-Minority Seats
# 5                                                 NaN
# 6                                                  36
# 7                            Total Seats For PWD  : 2
# 8                             PWD Reserved Common : 1
# 9                           Total Seats For DEF   : 2
# 10                            DEF Reserved Common : 1
# 11  Total EWS:7[Calculated EWS:1+Carry Forward Fir...
#
#                                                     1  \
# 0                                                 NaN
# 1                                                 NaN
# 2   Institute Code & Name : 6028 - Department of T...
# ...

# %%
df[409] #Comp start
#df[1013] # end
# Out:
#                                                     0  \
# 0   Main Group : 03 - Computer, Electronics, Elect...
# 1             Sub Group : 0301 - Computer Engineering
# 2                                         Sr No : 324
# 3                            Choice Code  : 101224510
# 4                                  Non-Minority Seats
# 5                                                 NaN
# 6                                                   8
# 7                            Total Seats For PWD  : 0
# 8                             PWD Reserved Common : 0
# 9                           Total Seats For DEF   : 0
# 10                            DEF Reserved Common : 0
# 11  Total EWS:3[Calculated EWS:1+Carry Forward Fir...
#
#                                                     1  \
# 0                                                 NaN
# 1                                                 NaN
# 2   Institute Code & Name : 1012 - Government Engi...
# ...

# %%
comp_df = df[409:1013]

# %%
mech_df = df[1709] #mechical

# %%
comp_df[0].iloc[:,1]
# Out:
# 0                                                   NaN
# 1                                                   NaN
# 2     Institute Code & Name : 1012 - Government Engi...
# 3                                   Status : Government
# 4                                        Minority Seats
# 5                                                   NaN
# 6                                                     0
# 7                                                     0
# 8                                                   NaN
# 9                                                     0
# 10                                                  NaN
# 11                                                  NaN
# Name: 1, dtype: object

# %%
t = "Institute Code & Name : 1012 - Government Engineering College, mumbai"
re.search(r'Mumbai|Navi Mumbai',t, re.IGNORECASE)
# Out:
# <re.Match object; span=(63, 69), match='mumbai'>

# %%
comp_df[1].iloc[:,1]
# Out:
# 0    Institute Code & Name : 1127 - Jagadambha Bahu...
# 1                                    Status : Un-Aided
# 2                                       Minority Seats
# 3                                                  NaN
# 4                                                    0
# 5                                                    0
# 6                                                  NaN
# 7                                                    0
# 8                                                  NaN
# 9                                                  NaN
# Name: 1, dtype: object

# %%
def comp_mumb(df):
    li_match = []
#     i = 0
    for i in range(0,14):
        li = comp_df[i].iloc[:,1]
#         print(li)
        for t in li:
            a = re.search(r'3210',str(t), re.IGNORECASE)
            if a != None:
                li_match.append(t)
#         i += 1
    return li_match

# %%
print(comp_mumb(comp_df))
# Out:
# []

# %%
clg_df = pd.read_excel('cut_off.xlsx',skiprows=[0,2])

# %%
list(clg_df.iloc[:,[0,1,2]].rename(columns={'Unnamed: 0':"CODE","Unnamed: 1":"College_Name","Unnamed: 2":"City"} ).set_index("CODE").index)
# Out:
# [3012,
#  3036,
#  3181,
#  3183,
#  3193,
#  3198,
#  3208,
#  3209,
#  3210,
#  3217,
#  3219,
#  3224,
#  3351,
#  3353,
#  3436,
#  3445,
#  3460,
#  3471,
#  3475,
#  3465,
#  3212,
#  3014,
#  3035,
#  3135,
#  3176,
#  3182,
#  3184,
#  3194,
#  3199,
#  3201,
#  3203,
#  3204,
#  3214,
#  3215,
#  3218,
#  3221,
#  3222,
#  3423,
#  3139,
#  3146,
#  3148,
#  3154,
#  3174,
#  3175,
#  3185,
#  3187,
#  3188,
#  3189,
#  3192,
#  3192,
#  3192,
#  3192,
#  3190,
#  3196,
#  3197,
#  3207,
#  3211,
#  3439]
